# %% [markdown]
# <a href="https://colab.research.google.com/github/LifsaDev/LifsaDev/blob/main/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('fivethirtyeight')

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-2e44ab78-8502-49e9-8bd5-8df19fd70515" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e44ab78-8502-49e9-8bd5-8df19fd70515">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AAPL.csv to AAPL (1).csv

# %%
AAPL=pd.read_csv('AAPL.csv')
AAPL
# Out:
#            Date        Open        High  ...       Close   Adj Close     Volume
# 0    2014-09-29  100.589996  100.690002  ...   99.620003   93.514290  142718700
# 1    2014-10-06   99.949997  102.379997  ...  100.730003   94.556244  280258200
# 2    2014-10-13  101.330002  101.779999  ...   97.669998   91.683792  358539800
# 3    2014-10-20   98.320000  105.489998  ...  105.220001   98.771042  358532900
# 4    2014-10-27  104.849998  108.040001  ...  108.000000  101.380676  220230600
# ..          ...         ...         ...  ...         ...         ...        ...
# 179  2018-03-05  175.210007  180.000000  ...  179.979996  179.979996  139852700
# 180  2018-03-12  180.289993  183.500000  ...  178.020004  178.020004  155417500
# 181  2018-03-19  177.320007  177.470001  ...  164.940002  164.940002  172670700
# 182  2018-03-26  168.070007  175.149994  ...  167.779999  167.779999  157898400
# 183  2018-03-29  167.804993  171.750000  ...  167.779999  167.779999   38398505
#
# ...

# %%
plt.figure(figsize=(12.5,4.5))
plt.plot(AAPL['Adj Close'], label='AAPL')
plt.title('Apple Adj.close price history')
plt.xlabel('sept.29, 2014 - mars.29, 2018')
plt.ylabel('Adj.Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()

# %%
SMA30=pd.DataFrame()
SMA30['Adj Close'] = AAPL['Adj Close'].rolling(window=30).mean()
SMA30
# Out:
#       Adj Close
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 179  166.220082
# 180  166.944129
# 181  167.154109
# 182  167.320155
# 183  167.665489
#
# [184 rows x 1 columns]

# %%
SMA100=pd.DataFrame()
SMA100['Adj Close'] = AAPL['Adj Close'].rolling(window=100).mean()
SMA100
# Out:
#       Adj Close
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 179  133.802447
# 180  134.523642
# 181  135.154237
# 182  135.928340
# 183  136.712275
#
# [184 rows x 1 columns]

# %%
plt.figure(figsize=(12.5,4.5))
plt.plot(AAPL['Adj Close'], label='AAPL')
plt.plot(SMA30['Adj Close'], label='SMA30')
plt.plot(SMA100['Adj Close'], label='SMA100')
plt.title('Apple Adj.close price history')
plt.xlabel('sept.29, 2014 - mars.29, 2018')
plt.ylabel('Adj.Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()

# %%
data=pd.DataFrame()
data['AAPL']=AAPL['Adj Close']
data['SMA30']=SMA30['Adj Close']
data['SMA100']=SMA100['Adj Close']
data
# Out:
#            AAPL       SMA30      SMA100
# 0     93.514290         NaN         NaN
# 1     94.556244         NaN         NaN
# 2     91.683792         NaN         NaN
# 3     98.771042         NaN         NaN
# 4    101.380676         NaN         NaN
# ..          ...         ...         ...
# 179  179.979996  166.220082  133.802447
# 180  178.020004  166.944129  134.523642
# 181  164.940002  167.154109  135.154237
# 182  167.779999  167.320155  135.928340
# 183  167.779999  167.665489  136.712275
#
# [184 rows x 3 columns]

# %%
def buy_sell(data):
  sigPriceBuy=[]
  sigPriceSell=[]
  flag=-1

  for i in range(len(data)):
    if data['SMA30'][i] > data['SMA100'][i]:
      if flag !=1:
        sigPriceBuy.append(data['AAPL'][i])
        sigPriceSell.append(np.nan)
        flag=1
      else:
        sigPriceBuy.append(np.nan)
        sigPriceSell.append(np.nan)

    elif data['SMA30'][i] < data['SMA100'][i]: 
      if flag !=0 :
        sigPriceBuy.append(np.nan)
        sigPriceSell.append(data['AAPL'][i])
      else:
        sigPriceBuy.append(np.nan)
        sigPriceSell.append(np.nan)

    else:
      sigPriceBuy.append(np.nan)
      sigPriceSell.append(np.nan)
    
  return( sigPriceBuy, sigPriceSell)

# %%
buy_sell = buy_sell(data)
data['buy_signal_price'] = buy_sell[0]
data['sel_signal_price'] = buy_sell[1]

# %%
data
# Out:
#            AAPL       SMA30      SMA100  buy_signal_price  sel_signal_price
# 0     93.514290         NaN         NaN               NaN               NaN
# 1     94.556244         NaN         NaN               NaN               NaN
# 2     91.683792         NaN         NaN               NaN               NaN
# 3     98.771042         NaN         NaN               NaN               NaN
# 4    101.380676         NaN         NaN               NaN               NaN
# ..          ...         ...         ...               ...               ...
# 179  179.979996  166.220082  133.802447               NaN               NaN
# 180  178.020004  166.944129  134.523642               NaN               NaN
# 181  164.940002  167.154109  135.154237               NaN               NaN
# 182  167.779999  167.320155  135.928340               NaN               NaN
# 183  167.779999  167.665489  136.712275               NaN               NaN
#
# [184 rows x 5 columns]

# %%
# !apt-get install python3.9

# %%
plt.figure(figsize=(12.6,4.6))
plt.plot(AAPL['Adj Close'], label='AAPL',alpha=0.35)
plt.plot(SMA30['Adj Close'], label='SMA30',alpha=0.35)
plt.plot(SMA100['Adj Close'], label='SMA100',alpha=0.35)
plt.scatter(data.index, data['buy_signal_price'], label='buy', marker= '^', color='green')
plt.scatter(data.index, data['sel_signal_price'], label='sell', marker= 'v', color='red')
plt.title('Apple Adj.close price history')
plt.xlabel('sept.29, 2014 - mars.29, 2018')
plt.ylabel('Adj.Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()
